# %%
# Importer les bibliothèques nécessaires
import pandas as pd #Lecture des données dans un type dataframe
import matplotlib.pyplot as plt #Dessiner des figures
import seaborn as sns #Méthodes statistiques
print("Importation des bibliothèques avec succès")
# Out:
# Importation des bibliothèques avec succès

# %%
# Lire le fichier CSV
data = pd.read_csv('gym_members_exercise_tracking.csv')

# Afficher les premières lignes du DataFrame pour comprendre les variables
data.head(20)
# Out:
#     Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0    56    Male         88.3        1.71      180      157           60
# 1    46  Female         74.9        1.53      179      151           66
# 2    32  Female         68.1        1.66      167      122           54
# 3    25    Male         53.2        1.70      190      164           56
# 4    38    Male         46.1        1.79      188      158           68
# 5    56  Female         58.0        1.68      168      156           74
# 6    36    Male         70.3        1.72      174      169           73
# 7    40  Female         69.7        1.51      189      141           64
# 8    28    Male        121.7        1.94      185      127           52
# 9    28    Male        101.8        1.84      169      136           64
# 10   41    Male        120.8        1.67      188      146           54
# 11   53    Male         51.7        1.70      175      152           72
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %%
print(data.isnull().sum())
print("Le nombre de ligne dupliquée: ",data.duplicated().sum())
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64
# Le nombre de ligne dupliquée:  0

# %%
# Apply one hot encoding to categorical columns
gym_data_encoded = pd.get_dummies(data, columns=['Gender', 'Workout_Type'])

# Display the first few rows to see the result
gym_data_encoded.head()
# Out:
#    Age  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56         88.3        1.71      180      157           60
# 1   46         74.9        1.53      179      151           66
# 2   32         68.1        1.66      167      122           54
# 3   25         53.2        1.70      190      164           56
# 4   38         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# 0                      1.69           1313.0            12.6
# 1                      1.30            883.0            33.9
# 2                      1.11            677.0            33.4
# 3                      0.59            532.0            28.8
# 4                      0.64            556.0            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    3.5                              4                 3
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Analyse exploratoire des variables

# Distribution de Gender
plt.figure(figsize=(10, 6))
sns.histplot(data['Gender'], kde=True)
plt.title('Distrubtion par sexe')
plt.xlabel('Masculin ou Féminin')
plt.ylabel('Nombre de membres')
plt.show()
# Out:
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=data, hue='Workout_Type')
plt.title('Nombre de membre par Workout')
plt.xlabel('Sexe')
plt.ylabel('Nombre de membres')
plt.legend(['Yoga', 'HIIT','Cardio','Strength'])
plt.show()

# %%
# Set up the matplotlib figure size
plt.figure(figsize=(12, 6))

# Plot histogram with KDE for age distribution by gender
sns.histplot(data=data, x="Age", hue="Gender", kde=True, bins=20, palette="viridis", element="step")

# Customize the plot
plt.title("Age Distribution by Gender")
plt.xlabel("Age")
plt.ylabel("Count")
plt.legend(title="Gender")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Display the plot
plt.show()
# Out:
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Get unique workout types
workout_types = data["Workout_Type"].unique()
num_types = len(workout_types)

# Define the plot size
plt.figure(figsize=(16, 10))
plt.suptitle("Age Distribution by Workout Type and Gender")

# Loop through each workout type and create a subplot
for i, workout_type in enumerate(workout_types, 1):
    plt.subplot(3, 3, i)  # Arrange subplots in a 3x3 grid (adjust as needed)
    subset = data[data["Workout_Type"] == workout_type]
    sns.histplot(data=subset, x="Age", hue="Gender", kde=True, bins=15, element="step", palette="viridis")
    
    # Customize each subplot
    plt.title(f"{workout_type}")
    plt.xlabel("Age")
    plt.ylabel("Count")
    plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\yassine\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Calculate the correlation matrix
correlation_matrix = gym_data_encoded.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
Workout = data.drop(columns=['Workout_Type'])
print (data)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
# One-hot encode the categorical columns
gym_data_encoded = pd.get_dummies(data, columns=['Gender'])
gym_data_encoded.head()
# Out:
#    Age  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56         88.3        1.71      180      157           60
# 1   46         74.9        1.53      179      151           66
# 2   32         68.1        1.66      167      122           54
# 3   25         53.2        1.70      190      164           56
# 4   38         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
X = data[['Weight (kg)','Fat_Percentage','Workout_Frequency (days/week)','Gender']]
y = data['Workout_Type']
print(y)
# Out:
# 0          Yoga
# 1          HIIT
# 2        Cardio
# 3      Strength
# 4      Strength
#          ...
# 968    Strength
# 969    Strength
# 970      Cardio
# 971        HIIT
# 972    Strength
# Name: Workout_Type, Length: 973, dtype: object

# %%
y.shape
# Out:
# (973,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode the target variable
y_encoded = label_encoder.fit_transform(y)

y_encoded
# Out:
# array([3, 1, 0, 2, 2, 1, 0, 0, 2, 0, 1, 1, 0, 1, 3, 2, 1, 0, 2, 1, 2, 0,
#        3, 3, 1, 3, 1, 2, 1, 1, 1, 3, 1, 0, 1, 2, 0, 2, 2, 2, 0, 0, 3, 0,
#        1, 2, 3, 0, 2, 0, 3, 0, 0, 2, 1, 0, 3, 0, 0, 1, 2, 3, 2, 2, 2, 0,
#        1, 0, 3, 1, 2, 1, 3, 0, 0, 2, 0, 0, 3, 1, 0, 3, 3, 2, 3, 2, 0, 2,
#        3, 1, 1, 0, 0, 1, 2, 0, 3, 0, 2, 0, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2,
#        1, 2, 3, 1, 2, 3, 0, 1, 3, 0, 3, 2, 2, 0, 2, 3, 0, 3, 3, 3, 2, 2,
#        3, 1, 3, 3, 0, 3, 2, 0, 1, 0, 1, 0, 0, 1, 2, 2, 2, 0, 3, 0, 3, 3,
#        2, 3, 0, 0, 2, 1, 0, 3, 0, 0, 0, 1, 3, 2, 0, 3, 3, 2, 0, 1, 3, 2,
#        1, 3, 0, 3, 1, 1, 0, 0, 2, 0, 2, 1, 1, 3, 3, 2, 0, 0, 3, 1, 2, 1,
#        1, 0, 2, 1, 3, 3, 0, 3, 3, 1, 3, 3, 1, 0, 0, 2, 3, 1, 2, 0, 0, 1,
#        2, 2, 1, 1, 2, 0, 3, 0, 1, 2, 2, 3, 2, 3, 0, 0, 2, 2, 1, 1, 2, 2,
#        0, 2, 1, 0, 3, 1, 1, 0, 3, 1, 2, 1, 0, 0, 0, 1, 3, 2, 0, 3, 2, 0,
#        2, 2, 3, 2, 0, 3, 1, 1, 3, 1, 2, 0, 2, 3, 0, 3, 3, 3, 2, 0, 0, 0,
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y_encoded,test_size=0.2, random_state=0)

# %%
ohe=OneHotEncoder()
ohe.fit(X[['Gender']])
print(ohe)
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Gender']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Female', 'Male'], dtype=object)]),
#                                                   ['Gender'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.0017460965282656282

# %%
from sklearn.metrics import classification_report

# Evaluate the model with zero_division to handle undefined metrics
print("Classification Report:\n", classification_report(y_test, y_pred, zero_division=1))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.29      0.59      0.39        46
#            1       0.21      0.21      0.21        42
#            2       0.29      0.36      0.32        47
#            3       1.00      0.00      0.00        60
#
#     accuracy                           0.27       195
#    macro avg       0.45      0.29      0.23       195
# weighted avg       0.49      0.27      0.21       195

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Copy the relevant columns to avoid modifying the original data
X = data[['Weight (kg)', 'Fat_Percentage', 'Workout_Frequency (days/week)', 'Gender']].copy()
y = data['Workout_Type'].copy()

# Encode categorical data if needed
X['Gender'] = label_encoder_gender.fit_transform(X['Gender'])
y = label_encoder_workout.fit_transform(y)


# Encode categorical data if needed
# Assuming 'Gender' and 'Workout_Type' are categorical
label_encoder_gender = LabelEncoder()
X['Gender'] = label_encoder_gender.fit_transform(X['Gender'])

label_encoder_workout = LabelEncoder()
y = label_encoder_workout.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Initialize and train the SVM classifier
clf = SVC(kernel='linear', class_weight='balanced')  # You can also try other kernels like 'rbf', 'poly', etc.
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.2512820512820513
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.23      0.47      0.31        40
#            1       0.22      0.14      0.17        51
#            2       0.25      0.24      0.24        55
#            3       0.34      0.20      0.26        49
#
#     accuracy                           0.25       195
#    macro avg       0.26      0.26      0.24       195
# weighted avg       0.26      0.25      0.24       195

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report

# Features and target variable
X = data[['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
          'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
          'Fat_Percentage', 'Water_Intake (liters)', 'Workout_Frequency (days/week)',
          'Experience_Level', 'BMI']]
y = data['Workout_Type']

# Column transformer to apply one-hot encoding to 'Gender' and scaling to numerical features
preprocessor = make_column_transformer(
    (OneHotEncoder(), ['Gender']),
    (StandardScaler(), ['Age', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM', 
                        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned', 
                        'Fat_Percentage', 'Water_Intake (liters)', 
                        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI']),
    remainder='passthrough'
)

# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create an SVM pipeline with the preprocessor and classifier
svm_model = make_pipeline(preprocessor, SVC(kernel='linear'))

# Train the model
svm_model.fit(X_train, y_train)

# Predictions and evaluation
y_pred = svm_model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Cardio       0.24      0.60      0.34        40
#         HIIT       0.00      0.00      0.00        51
#     Strength       0.28      0.27      0.28        55
#         Yoga       0.26      0.20      0.23        49
#
#     accuracy                           0.25       195
#    macro avg       0.19      0.27      0.21       195
# weighted avg       0.19      0.25      0.21       195

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Using RBF kernel with class weight balanced
svm_model = make_pipeline(preprocessor, SVC(kernel='rbf', class_weight='balanced'))

# Define a parameter grid for hyperparameter tuning
param_grid = {
    'svc__C': [0.1, 1, 10],
    'svc__gamma': [0.01, 0.1, 1]
}

# Using GridSearchCV to find the best parameters
grid_search = GridSearchCV(svm_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Predict and evaluate
y_pred = grid_search.predict(X_test)
print("Best Parameters:", grid_search.best_params_)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'svc__C': 0.1, 'svc__gamma': 0.01}
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Cardio       0.21      1.00      0.34        40
#         HIIT       0.00      0.00      0.00        51
#     Strength       0.00      0.00      0.00        55
#         Yoga       0.00      0.00      0.00        49
#
#     accuracy                           0.21       195
#    macro avg       0.05      0.25      0.09       195
# weighted avg       0.04      0.21      0.07       195
# C:\Users\yassine\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Using RBF kernel with class weight balanced
svm_model = make_pipeline(preprocessor, SVC(kernel='rbf', class_weight='balanced'))

# Define a parameter grid for tuning
param_grid = {
    'svc__C': [0.1, 1, 10],  # Try a range of regularization values
    'svc__gamma': [0.01, 0.1, 1]  # Try a range of gamma values for RBF kernel
}

# Use GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(svm_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Evaluate the best model found by grid search
y_pred = grid_search.predict(X_test)
print("Best Parameters:", grid_search.best_params_)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'svc__C': 0.1, 'svc__gamma': 0.01}
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Cardio       0.21      1.00      0.34        40
#         HIIT       0.00      0.00      0.00        51
#     Strength       0.00      0.00      0.00        55
#         Yoga       0.00      0.00      0.00        49
#
#     accuracy                           0.21       195
#    macro avg       0.05      0.25      0.09       195
# weighted avg       0.04      0.21      0.07       195
# C:\Users\yassine\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
